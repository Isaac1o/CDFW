# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt

# %%
# Near-Sided Perspective Projection
m = Basemap(projection='nsper', lon_0=-119.41, lat_0=36.77, satellite_height=150000.0, resolution='l')
m.drawcoastlines()
m.fillcontinents(color='coral', lake_color='aqua')
m.drawmapboundary(fill_color='aqua')
m.drawstates()
m.drawcountries()
plt.show()

# %%
# Near-Sided Perspective Projection
plt.figure(figsize=(10,10))
m = Basemap(projection='lcc', lat_1=42.208210,lat_2=42.096833,lat_0=37.506088,lon_0=-120.050484, width=1199900,height=1100000, resolution=None)
# m.drawcoastlines()
# m.fillcontinents(color='coral', lake_color='aqua')
# m.drawmapboundary(fill_color='aqua')
# m.drawstates()
# m.drawcountries()
# m.drawcounties()
# m.drawlsmask(land_color='coral',ocean_color='aqua',lakes=True)
m.bluemarble(scale=7)
plt.show()

# %%
m.ymin
# Out:
# 0.0
